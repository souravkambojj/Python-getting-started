# %%
empdata = {'EmpId':[1,2,3,4,5,6,7,8,9],'EmpName':['sam','smith','tom','denis','danny','john','siah','tam','pind'],'salary':[500,700,900,400,1100,210,200,3000,260],'DepId':['e','i','e','i','h','h','e','i','h']}

# %%
depdata = {'id':['a','e','h','i','j'],'name':['ABC','Engg','HR','IT','JKL']}

# %%
import pandas as pd

empdf = pd.DataFrame(empdata)
depdf = pd.DataFrame(depdata)

# %%
print(empdf)
# Out:
#    EmpId EmpName  salary DepId
# 0      1     sam     500     e
# 1      2   smith     700     i
# 2      3     tom     900     e
# 3      4   denis     400     i
# 4      5   danny    1100     h
# 5      6    john     210     h
# 6      7    siah     200     e
# 7      8     tam    3000     i
# 8      9    pind     260     h

# %%
print(depdf)
# Out:
#   id  name
# 0  a   ABC
# 1  e  Engg
# 2  h    HR
# 3  i    IT
# 4  j   JKL

# %%
depdf.columns
# Out:
# Index(['id', 'name'], dtype='object')

# %% [markdown]
# # **Rename Columns**

# %%
depdf.rename(columns={'id':'DepId','name':'DepName'},inplace=True)

# %% [markdown]
# # **Merge**

# %%
df = pd.merge(empdf,depdf, how='inner', on='DepId')
df
# Out:
#    EmpId EmpName  salary DepId DepName
# 0      1     sam     500     e    Engg
# 1      3     tom     900     e    Engg
# 2      7    siah     200     e    Engg
# 3      2   smith     700     i      IT
# 4      4   denis     400     i      IT
# 5      8     tam    3000     i      IT
# 6      5   danny    1100     h      HR
# 7      6    john     210     h      HR
# 8      9    pind     260     h      HR

# %% [markdown]
# # **Sorting**

# %%
df.sort_values(by='EmpName')
# Out:
#    EmpId EmpName  salary DepId DepName
# 6      5   danny    1100     h      HR
# 4      4   denis     400     i      IT
# 7      6    john     210     h      HR
# 8      9    pind     260     h      HR
# 0      1     sam     500     e    Engg
# 2      7    siah     200     e    Engg
# 3      2   smith     700     i      IT
# 5      8     tam    3000     i      IT
# 1      3     tom     900     e    Engg

# %%
df.sort_values(by='EmpName').reset_index(drop=True) #inplace=True
# Out:
#    EmpId EmpName  salary DepId DepName
# 0      5   danny    1100     h      HR
# 1      4   denis     400     i      IT
# 2      6    john     210     h      HR
# 3      9    pind     260     h      HR
# 4      1     sam     500     e    Engg
# 5      7    siah     200     e    Engg
# 6      2   smith     700     i      IT
# 7      8     tam    3000     i      IT
# 8      3     tom     900     e    Engg

# %%
df.sort_values(by='EmpName',ascending=False).reset_index(drop=True)
# Out:
#    EmpId EmpName  salary DepId DepName
# 0      3     tom     900     e    Engg
# 1      8     tam    3000     i      IT
# 2      2   smith     700     i      IT
# 3      7    siah     200     e    Engg
# 4      1     sam     500     e    Engg
# 5      9    pind     260     h      HR
# 6      6    john     210     h      HR
# 7      4   denis     400     i      IT
# 8      5   danny    1100     h      HR

# %%
df.sort_values(by=['EmpName','salary'],ascending=[True,False]).reset_index(drop=True)
# Out:
#    EmpId EmpName  salary DepId DepName
# 0      5   danny    1100     h      HR
# 1      4   denis     400     i      IT
# 2      6    john     210     h      HR
# 3      9    pind     260     h      HR
# 4      1     sam     500     e    Engg
# 5      7    siah     200     e    Engg
# 6      2   smith     700     i      IT
# 7      8     tam    3000     i      IT
# 8      3     tom     900     e    Engg

# %% [markdown]
# # **Highest salary of each group**

# %%
df.groupby('DepName').max()
# Out:
#          EmpId EmpName  salary DepId
# DepName
# Engg         7     tom     900     e
# HR           9    pind    1100     h
# IT           8     tam    3000     i

# %%
df.groupby('DepName').max().reset_index()
# Out:
#   DepName  EmpId EmpName  salary DepId
# 0    Engg      7     tom     900     e
# 1      HR      9    pind    1100     h
# 2      IT      8     tam    3000     i

# %%
df.groupby('DepName').max().reset_index()[['DepName','EmpName','salary']]
# Out:
#   DepName EmpName  salary
# 0    Engg     tom     900
# 1      HR    pind    1100
# 2      IT     tam    3000

# %% [markdown]
# # **2nd highest salary of each group**

# %%
  df.groupby('DepName').head(2)
# Out:
#    EmpId EmpName  salary DepId DepName
# 0      1     sam     500     e    Engg
# 1      3     tom     900     e    Engg
# 3      2   smith     700     i      IT
# 4      4   denis     400     i      IT
# 6      5   danny    1100     h      HR
# 7      6    john     210     h      HR

# %%
  df.groupby('DepName').tail(2)
# Out:
#    EmpId EmpName  salary DepId DepName
# 1      3     tom     900     e    Engg
# 2      7    siah     200     e    Engg
# 4      4   denis     400     i      IT
# 5      8     tam    3000     i      IT
# 7      6    john     210     h      HR
# 8      9    pind     260     h      HR

# %%
#n highest values
df.groupby('DepName')['salary'].nlargest(2).reset_index()
# Out:
#   DepName  level_1  salary
# 0    Engg        1     900
# 1    Engg        0     500
# 2      HR        6    1100
# 3      HR        8     260
# 4      IT        5    3000
# 5      IT        3     700

# %%
df.groupby('DepName')['salary'].nlargest(2).reset_index().drop('level_1',axis=1)
# Out:
#   DepName  salary
# 0    Engg     900
# 1    Engg     500
# 2      HR    1100
# 3      HR     260
# 4      IT    3000
# 5      IT     700

# %%
nhighest_df = df.groupby('DepName')['salary'].nlargest(2).reset_index().drop('level_1',axis=1)
nhighest_df
# Out:
#   DepName  salary
# 0    Engg     900
# 1    Engg     500
# 2      HR    1100
# 3      HR     260
# 4      IT    3000
# 5      IT     700

# %%
nhighest_df.groupby('DepName').tail(1)
# Out:
#   DepName  salary
# 1    Engg     500
# 3      HR     260
# 5      IT     700

# %%
nhighest_df.groupby('DepName').tail(1).reset_index(drop=True)
# Out:
#   DepName  salary
# 0    Engg     500
# 1      HR     260
# 2      IT     700
